# %%
import numpy as np
import pandas as pd
import scipy

# %%
#read file
file_location = "/home/sym/BA501_2Session/"
file_name = "orders_new.csv"
my_data = pd.read_csv(file_location + file_name)

# %%
my_data.head(5)
# Out:
#   country        date  experiment_id              order_id  spend_usd  \
# 0      US  2017-04-02       12624549   6720123150182430132      49.99
# 1      US  2017-04-01       12624549  17511438899767627798       0.99
# 2      US  2017-04-04       12624549   1549342062436664018      39.99
# 3      US  2017-04-04       12624549   7771425263197855716      19.99
# 4      US  2017-04-01       12624549  17943210556580942992      19.99
#
#                user_id      vertical
# 0  3659561261588336546  ANDROID_APPS
# 1  3659561261588336546  ANDROID_APPS
# 2  3659561261588336546  ANDROID_APPS
# 3  3659561261588336546  ANDROID_APPS
# 4  3659561261588336546  ANDROID_APPS

# %%
#How do you handle duplicate values in a dataset in Python?
#using "pandas"
#Checking for duplicates
my_data.shape
# Out:
# (39958, 7)

# %%
my_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 39928    False
# 39929    False
# 39930    False
# 39931    False
# 39932    False
# 39933    False
# 39934    False
# 39935    False
# 39936    False
# 39937    False
# 39938    False
# 39939    False
# 39940    False
# 39941    False
# 39942    False
# 39943    False
# 39944    False
# 39945    False
# 39946    False
# 39947    False
# 39948    False
# 39949    False
# 39950    False
# 39951    False
# 39952    False
# 39953    False
# 39954    False
# ...

# %%
my_data.duplicated('country')
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 39928     True
# 39929     True
# 39930     True
# 39931     True
# 39932     True
# 39933     True
# 39934     True
# 39935     True
# 39936     True
# 39937     True
# 39938     True
# 39939     True
# 39940     True
# 39941     True
# 39942     True
# 39943     True
# 39944     True
# 39945     True
# 39946     True
# 39947     True
# 39948     True
# 39949     True
# 39950     True
# 39951     True
# 39952     True
# 39953     True
# 39954     True
# ...

# %%
#There is no duplicates in order table, whole table will be output
#Dropping duplicates from a particular column: df.drop_duplicates([‘col1’], keep = '')
my_data.drop_duplicates()
# Out:
#       country        date  experiment_id              order_id  spend_usd  \
# 0          US  2017-04-02       12624549   6720123150182430132  49.990000
# 1          US  2017-04-01       12624549  17511438899767627798   0.990000
# 2          US  2017-04-04       12624549   1549342062436664018  39.990000
# 3          US  2017-04-04       12624549   7771425263197855716  19.990000
# 4          US  2017-04-01       12624549  17943210556580942992  19.990000
# 5          US  2017-04-01       12624549  14181259234722501452   9.990000
# 6          US  2017-04-06       12624549   2216871028985838700  19.990000
# 7          US  2017-04-05       12624548   2401579091544890692   0.990000
# 8          US  2017-04-06       12624548   6311345639701552883   4.990000
# 9          US  2017-04-05       12624549   7059034589483462446  49.990000
# 10         US  2017-04-01       12624548   8047726651081695000  18.990000
# 11         US  2017-04-02       12624548   5603707383013558380   0.990000
# ...
